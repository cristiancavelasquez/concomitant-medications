# %%
#Load the libraries
import pandas as pd
import numpy as np
from itertools import permutations,combinations

# %%
#create a function that finds pairs and list them in a column. Using A and B as a stand in
def find_pairs(x):
    pairs = pd.DataFrame(list(permutations(x.values,2)),columns=["A","B"])
    return pairs

# %%
#Load in the dataset and check the head of the data
dataset=pd.read_excel("/content/drive/MyDrive/concomitancia/concomitancia cruz verde2.xlsm")
dataset = dataset.loc[:,["Receta","descripcion"]]

# %%
dataset
# Out:
#            Receta                              descripcion
# 0      1190414206               SINALGEN 5MG/325MG TABLETA
# 1      1190414206                  TAMSULON 0.4MG CAPSULAS
# 2      1190414525                   NUCTIS D  GOTAS ORALES
# 3      1190414525  BEDOYECTA TRI  INYECTABLE INTRAMUSCULAR
# 4      1190414525        ESCITALOPRAM LNI 10MG COMPRIMIDOS
# ...           ...                                      ...
# 15572  1237491293                    FLEXIMAX NAP  TABLETA
# 15573  1237491293                      HERREX FOL  GRAGEAS
# 15574  1237491319                    FLEXIMAX NAP  TABLETA
# 15575  1237491319  BEDOYECTA TRI  INYECTABLE INTRAMUSCULAR
# 15576  1237491319       B-VIT HT  INYECTABLE INTRAMUSCULAR
#
# [15577 rows x 2 columns]

# %%
#Group the products by Order ID then apply the function
dataset_combo =dataset.groupby('Receta')['descripcion'].apply(find_pairs).reset_index(drop=True)

# %%
#  Calculate how often each item item_a occurs with the items in item_b
dataset_combo2 =dataset_combo.groupby(['A','B']).size()
dataset_combo2
# Out:
# A                                       B
# 2D DERMATOLOGY  CREMA DERMICA           ENGYSTOL  TABLETA                 1
# A-CERUMEN  SOLUCION O SUSPENSION OTICA  ACETAMINOFEN LNI 500MG TABLETA    1
#                                         ACTIN 120MG TABLETA               1
#                                         BENZIRIN VERDE  COLUTORIO         1
#                                         DESLODEX D 2.5/20MG CAPSULAS      1
#                                                                          ..
# ZYPREXA 10MG INYECTABLE INTRAMUSCULAR   HIDROCLOROTIA.LNI 25MG TABLETA    1
#                                         METFORMINA SDZ 850MG TABLETA      1
#                                         VALSARTAN M.K 160MG TABLETA       1
# ZYRTEC 10MG/ML GOTAS ORALES             ANEMIDOX  GOTAS ORALES            2
#                                         FARMA D 200UI GOTAS ORALES        2
# Length: 39961, dtype: int64

# %%
#create a sorted dataframe by the most frequent combinations.
dataset =dataset_combo2.reset_index()
dataset.columns = ['A','B',"Size"]
dataset.sort_values(by='Size',ascending =False, inplace =True)
dataset
# Out:
#                                           A  \
# 2833                     ANEMIDOX  CAPSULAS
# 1522                   ALBISEC ONE  TABLETA
# 1524                   ALBISEC ONE  TABLETA
# 11116              DECADRON NISTATIN  OVULO
# 11117              DECADRON NISTATIN  OVULO
# ...                                     ...
# 14933                   EPIDUO  GEL DERMICO
# 14932                   EPIDUO  GEL DERMICO
# 14930                     EPAX EC  CAPSULAS
# 14929                     EPAX EC  CAPSULAS
# 19980  FLUIMUCIL 600MG TABLETA EFERVESCENTE
#
#                                          B  Size
# 2833              DECADRON NISTATIN  OVULO    42
# 1522                    ANEMIDOX  CAPSULAS    42
# 1524              DECADRON NISTATIN  OVULO    42
# 11116                 ALBISEC ONE  TABLETA    42
# 11117                   ANEMIDOX  CAPSULAS    42
# ...                                    ...   ...
# 14933          BACTRIM F 160/800MG TABLETA     1
# 14932      APIVITA AQUA BEE  CREMA DERMICA     1
# 14930             NITAHELMIN 500MG TABLETA     1
# 14929  NEUROBION  INYECTABLE INTRAMUSCULAR     1
# 19980         BUDEMAR 200MCG AEROSOL BUCAL     1
#
# [39961 rows x 3 columns]

# %%
dataset.to_excel("result.xlsx")
